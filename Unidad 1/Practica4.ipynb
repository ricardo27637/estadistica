# %% [markdown]
# <a href="https://colab.research.google.com/github/ricardo27637/estadistica/blob/main/Unidad%201/Practica4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Practica 4
#
# tablas de frecuencia

# %%
#creamos una lista vacia  que representa la edad de las 100 personas
import random
edades=[]

#Hacemos un ciclo para general 100 numero aleatorios que representan la edad de las personas
#generamos un numero aleatorio con la funcion randint y lo guardamos en la variable
#numero alterno
for i in range(100):
  numero_aleatorio=random.randint(18,70)
#agregamos el numero aleatorio a la lista de valores
  edades.append(numero_aleatorio)
#imprimimos la lista de edades
print(edades)
# Out:
# [33, 57, 35, 41, 44, 39, 18, 22, 34, 41, 27, 50, 54, 55, 32, 39, 45, 45, 66, 68, 28, 61, 53, 29, 57, 32, 56, 49, 45, 32, 68, 50, 34, 23, 30, 59, 37, 53, 27, 20, 67, 19, 63, 50, 35, 37, 40, 52, 69, 40, 68, 61, 18, 62, 29, 51, 60, 41, 40, 38, 36, 36, 44, 22, 35, 27, 22, 18, 47, 56, 53, 29, 19, 59, 44, 68, 29, 18, 65, 38, 70, 41, 52, 20, 65, 64, 66, 52, 49, 35, 20, 37, 34, 53, 45, 25, 35, 36, 47, 28]

# %%
import pandas as pd

#crear un dataframe de pandas con los numeros aleatorios
df=pd.DataFrame(edades,columns=['edades'])
df.head()
# Out:
#    edades
# 0      33
# 1      57
# 2      35
# 3      41
# 4      44

# %%
#calcular la tabla de distribucion de frecuencias
tabla_frecuencias=df['edades'].value_counts().reset_index()
tabla_frecuencias.columns =['edades', 'Frecuencia']
tabla_frecuencias = tabla_frecuencias.sort_values(by='edades')

#imprimir la tabla
print("tabla de frecuencias")
tabla_frecuencias
# Out:
# tabla de frecuencias
#     edades  Frecuencia
# 4       18           4
# 19      19           2
# 12      20           3
# 14      22           3
# 40      23           1
# 43      25           1
# 10      27           3
# 23      28           2
# 6       29           4
# 39      30           1
# 9       32           3
# 34      33           1
# 13      34           3
# 0       35           5
# 17      36           3
# 8       37           3
# 20      38           2
# 29      39           2
# 7       40           3
# 1       41           4
# 16      44           3
# 5       45           4
# 21      47           2
# 18      49           2
# 11      50           3
# 30      51           1
# 15      52           3
# 3       53           4
# 42      54           1
# 41      55           1
# 26      56           2
# 25      57           2
# 22      59           2
# 33      60           1
# 27      61           2
# 35      62           1
# 37      63           1
# 32      64           1
# 24      65           2
# 28      66           2
# 38      67           1
# 2       68           4
# 36      69           1
# 31      70           1

# %%
tabla_frecuencias['Frecuencia relativa'] = tabla_frecuencias['Frecuencia'] /100
tabla_frecuencias
# Out:
#     edades  Frecuencia  Frecuencia relativa
# 4       18           4                 0.04
# 19      19           2                 0.02
# 12      20           3                 0.03
# 14      22           3                 0.03
# 40      23           1                 0.01
# 43      25           1                 0.01
# 10      27           3                 0.03
# 23      28           2                 0.02
# 6       29           4                 0.04
# 39      30           1                 0.01
# 9       32           3                 0.03
# 34      33           1                 0.01
# 13      34           3                 0.03
# 0       35           5                 0.05
# 17      36           3                 0.03
# 8       37           3                 0.03
# 20      38           2                 0.02
# 29      39           2                 0.02
# 7       40           3                 0.03
# 1       41           4                 0.04
# 16      44           3                 0.03
# 5       45           4                 0.04
# 21      47           2                 0.02
# 18      49           2                 0.02
# 11      50           3                 0.03
# 30      51           1                 0.01
# 15      52           3                 0.03
# 3       53           4                 0.04
# 42      54           1                 0.01
# 41      55           1                 0.01
# 26      56           2                 0.02
# 25      57           2                 0.02
# 22      59           2                 0.02
# 33      60           1                 0.01
# 27      61           2                 0.02
# 35      62           1                 0.01
# 37      63           1                 0.01
# 32      64           1                 0.01
# 24      65           2                 0.02
# 28      66           2                 0.02
# 38      67           1                 0.01
# 2       68           4                 0.04
# 36      69           1                 0.01
# 31      70           1                 0.01

# %%
tabla_frecuencias['Frec porcentual'] = tabla_frecuencias['Frecuencia']/100*100
tabla_frecuencias
# Out:
#     edades  Frecuencia  Frecuencia relativa  Frec porcentual
# 4       18           4                 0.04              4.0
# 19      19           2                 0.02              2.0
# 12      20           3                 0.03              3.0
# 14      22           3                 0.03              3.0
# 40      23           1                 0.01              1.0
# 43      25           1                 0.01              1.0
# 10      27           3                 0.03              3.0
# 23      28           2                 0.02              2.0
# 6       29           4                 0.04              4.0
# 39      30           1                 0.01              1.0
# 9       32           3                 0.03              3.0
# 34      33           1                 0.01              1.0
# 13      34           3                 0.03              3.0
# 0       35           5                 0.05              5.0
# 17      36           3                 0.03              3.0
# 8       37           3                 0.03              3.0
# 20      38           2                 0.02              2.0
# 29      39           2                 0.02              2.0
# 7       40           3                 0.03              3.0
# 1       41           4                 0.04              4.0
# 16      44           3                 0.03              3.0
# 5       45           4                 0.04              4.0
# 21      47           2                 0.02              2.0
# 18      49           2                 0.02              2.0
# 11      50           3                 0.03              3.0
# 30      51           1                 0.01              1.0
# 15      52           3                 0.03              3.0
# 3       53           4                 0.04              4.0
# 42      54           1                 0.01              1.0
# 41      55           1                 0.01              1.0
# 26      56           2                 0.02              2.0
# 25      57           2                 0.02              2.0
# 22      59           2                 0.02              2.0
# 33      60           1                 0.01              1.0
# 27      61           2                 0.02              2.0
# 35      62           1                 0.01              1.0
# 37      63           1                 0.01              1.0
# 32      64           1                 0.01              1.0
# 24      65           2                 0.02              2.0
# 28      66           2                 0.02              2.0
# 38      67           1                 0.01              1.0
# 2       68           4                 0.04              4.0
# 36      69           1                 0.01              1.0
# 31      70           1                 0.01              1.0

# %%
tabla_frecuencias['Frec acumulada'] = tabla_frecuencias['Frecuencia'].cumsum()
tabla_frecuencias
# Out:
#     edades  Frecuencia  Frecuencia relativa  Frec porcentual  Frec acumulada
# 4       18           4                 0.04              4.0               4
# 19      19           2                 0.02              2.0               6
# 12      20           3                 0.03              3.0               9
# 14      22           3                 0.03              3.0              12
# 40      23           1                 0.01              1.0              13
# 43      25           1                 0.01              1.0              14
# 10      27           3                 0.03              3.0              17
# 23      28           2                 0.02              2.0              19
# 6       29           4                 0.04              4.0              23
# 39      30           1                 0.01              1.0              24
# 9       32           3                 0.03              3.0              27
# 34      33           1                 0.01              1.0              28
# 13      34           3                 0.03              3.0              31
# 0       35           5                 0.05              5.0              36
# 17      36           3                 0.03              3.0              39
# 8       37           3                 0.03              3.0              42
# 20      38           2                 0.02              2.0              44
# 29      39           2                 0.02              2.0              46
# 7       40           3                 0.03              3.0              49
# 1       41           4                 0.04              4.0              53
# 16      44           3                 0.03              3.0              56
# 5       45           4                 0.04              4.0              60
# 21      47           2                 0.02              2.0              62
# 18      49           2                 0.02              2.0              64
# 11      50           3                 0.03              3.0              67
# 30      51           1                 0.01              1.0              68
# 15      52           3                 0.03              3.0              71
# 3       53           4                 0.04              4.0              75
# 42      54           1                 0.01              1.0              76
# 41      55           1                 0.01              1.0              77
# 26      56           2                 0.02              2.0              79
# 25      57           2                 0.02              2.0              81
# 22      59           2                 0.02              2.0              83
# 33      60           1                 0.01              1.0              84
# 27      61           2                 0.02              2.0              86
# 35      62           1                 0.01              1.0              87
# 37      63           1                 0.01              1.0              88
# 32      64           1                 0.01              1.0              89
# 24      65           2                 0.02              2.0              91
# 28      66           2                 0.02              2.0              93
# 38      67           1                 0.01              1.0              94
# 2       68           4                 0.04              4.0              98
# 36      69           1                 0.01              1.0              99
# 31      70           1                 0.01              1.0             100
